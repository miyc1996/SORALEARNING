# %% [markdown]
# ### 训练一个sora模型的准备工作，video caption和算力评估
# - 训练Sora模型
# [原理图](https://camo.githubusercontent.)
# [流程图](https://camo.githubusercontent.)
# [训练链路](https://camo.githubusercontent.)
#
# - 数据准备
# 开源数据集介绍
# - 数据预处理
# 目前主流LLM框架缺乏针对 video数据 统一便捷的管理和处理能力，且多模态数据处理标准方案缺失
# - 模型选型和训练
#
# - 视频VQVAE
# [原理图](https://camo.githubusercontent.)
#
# - Diffusion Transformer
# - Video-caption
# ### 动手学习AI视频
# - 现有AI视频软件盘点
# - Sora的优势
# - Diffusion原理
# ![image.png](attachment:image.png)
# - Transformers原理
# Attention机制
# ![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)
# - 提示词影响
# ![image-4.png](attachment:image-4.png)
# - 视频生成大致流程
# 先使用ChatGPT，写分镜剧本。
# 使用SD，MJ等软件画图。
# 最后利用SVD，Pika，Runway等软件生成视频
